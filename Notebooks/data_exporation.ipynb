# %%
import pandas as pd

# %%
path = '../Resources/loan.csv'

df = pd.read_csv(path)
df.head()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_17312\1490347542.py:3: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... total_bal_il il_util  \
# 0     10.65       162.87     B        B2  ...          NaN     NaN
# 1     15.27        59.83     C        C4  ...          NaN     NaN
# 2     15.96        84.33     C        C5  ...          NaN     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887379 entries, 0 to 887378
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           887379 non-null  int64
#  1   member_id                    887379 non-null  int64
#  2   loan_amnt                    887379 non-null  float64
#  3   funded_amnt                  887379 non-null  float64
#  4   funded_amnt_inv              887379 non-null  float64
#  5   term                         887379 non-null  object
#  6   int_rate                     887379 non-null  float64
#  7   installment                  887379 non-null  float64
#  8   grade                        887379 non-null  object
#  9   sub_grade                    887379 non-null  object
#  10  emp_title                    835917 non-null  object
#  11  emp_length                   842554 non-null  object
# ...

# %%
df.shape
# Out:
# (887379, 74)

# %%
# We can see that columns:

# annual_inc_joint
# dti_joint
# verification_status_joint
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# inq_fi
# total_cu_tl
# inq_last_12m
# has few non-null values and probably can be removed from the dataset. 

# These contain less that 20% of the data and could be removed from the dataset
# desc
# mths_since_last_record

# %%
for column in df.columns:
    print('\n------------------------------------------------')
    print('\ncolumn name: ' + column + '\n')
    print('------------------------------------------------\n')
    print(df[column].describe())
# Out:
# ------------------------------------------------
#
# column name: id
#
# ------------------------------------------------
#
# count    8.873790e+05
# mean     3.246513e+07
# std      2.282734e+07
# min      5.473400e+04
# 25%      9.206643e+06
# 50%      3.443327e+07
# 75%      5.490814e+07
# max      6.861706e+07
# Name: id, dtype: float64
#
# ------------------------------------------------
#
# column name: member_id
#
# ------------------------------------------------
#
# count    8.873790e+05
# mean     3.500182e+07
# std      2.411335e+07
# min      7.047300e+04
# 25%      1.087713e+07
# 50%      3.709528e+07
# 75%      5.847135e+07
# max      7.354484e+07
# Name: member_id, dtype: float64
#
# ------------------------------------------------
#
# column name: loan_amnt
#
# ------------------------------------------------
#
# count    887379.000000
# mean      14755.264605
# std        8435.455601
# min         500.000000
# 25%        8000.000000
# 50%       13000.000000
# ...

# %%
df.sort_values(['loan_amnt','grade'], ascending=[False, True]).head(20)
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128   1068159    1302729    35000.0      35000.0     35000.000000   36 months
# 276   1065896    1300036    35000.0      35000.0     35000.000000   36 months
# 611   1056174    1287750    35000.0      35000.0     35000.000000   36 months
# 964   1054438    1286069    35000.0      35000.0     35000.000000   36 months
# 1256  1053569    1285157    35000.0      35000.0     35000.000000   36 months
# 1352  1049941    1281351    35000.0      35000.0     35000.000000   36 months
# 1533  1049279    1280492    35000.0      35000.0     34950.000000   36 months
# 1990  1042402    1265666    35000.0      35000.0     34200.000000   36 months
# 2930  1029488    1258856    35000.0      35000.0     35000.000000   36 months
# 2968  1028819    1258172    35000.0      35000.0     35000.000000   36 months
# 3010  1019275    1247957    35000.0      35000.0     34700.000000   36 months
# ...

# %%
df['loan_amnt'].value_counts()
# Out:
# 10000.0    61837
# 12000.0    50183
# 15000.0    47210
# 20000.0    46932
# 35000.0    36368
#            ...
# 550.0          1
# 925.0          1
# 750.0          1
# 725.0          1
# 950.0          1
# Name: loan_amnt, Length: 1372, dtype: int64

# %%
df['grade'].value_counts()
# Out:
# B    254535
# C    245860
# A    148202
# D    139542
# E     70705
# F     23046
# G      5489
# Name: grade, dtype: int64

# %%
df['sub_grade'].value_counts()
# Out:
# B3    56323
# B4    55626
# C1    53387
# C2    52236
# C3    50161
# C4    48857
# B5    48833
# B2    48781
# B1    44972
# A5    44816
# C5    41219
# D1    36238
# A4    34531
# D2    29803
# D3    26554
# D4    25558
# A3    23457
# A1    22913
# A2    22485
# D5    21389
# E1    18268
# E2    17004
# E3    14134
# E4    11724
# E5     9575
# F1     7218
# F2     5392
# F3     4433
# F4     3409
# F5     2594
# G1     1871
# G2     1398
# G3      981
# G4      663
# G5      576
# Name: sub_grade, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
# ...

# %%
for column in df.columns:
    print('\n------------------------------------------------')
    print('\ncolumn name: ' + column + '\n')
    print('------------------------------------------------\n')
    print(df[column].value_counts())
# Out:
# ------------------------------------------------
#
# column name: id
#
# ------------------------------------------------
#
# 1077501     1
# 59561165    1
# 61448183    1
# 61408303    1
# 60964818    1
#            ..
# 28983843    1
# 28933642    1
# 28913676    1
# 28933755    1
# 36271262    1
# Name: id, Length: 887379, dtype: int64
#
# ------------------------------------------------
#
# column name: member_id
#
# ------------------------------------------------
#
# 1296599     1
# 63494885    1
# 65566896    1
# 65527018    1
# 65006696    1
#            ..
# 31507047    1
# 31456838    1
# 31436866    1
# 31456960    1
# 38982659    1
# Name: member_id, Length: 887379, dtype: int64
#
# ------------------------------------------------
#
# column name: loan_amnt
#
# ------------------------------------------------
#
# 10000.0    61837
# 12000.0    50183
# 15000.0    47210
# 20000.0    46932
# 35000.0    36368
#            ...
# 550.0          1
# 925.0          1
# ...

# %%
income = df['annual_inc']

income = income.dropna()

# %%
income = income.sort_values()
income
# Out:
# 484446          0.0
# 531886          0.0
# 540456       1200.0
# 475046       1770.0
# 42437        1896.0
#             ...
# 490862    8700000.0
# 866973    8706582.0
# 684000    8900060.0
# 506740    9000000.0
# 697244    9500000.0
# Name: annual_inc, Length: 887375, dtype: float64

# %%
income = income.reset_index(drop=True)
income
# Out:
# 0               0.0
# 1               0.0
# 2            1200.0
# 3            1770.0
# 4            1896.0
#             ...
# 887370    8700000.0
# 887371    8706582.0
# 887372    8900060.0
# 887373    9000000.0
# 887374    9500000.0
# Name: annual_inc, Length: 887375, dtype: float64

# %%
yticks = range(0, 1000001, 50000)

income_df = pd.DataFrame({'income' : income})
ax = income_df.plot.line()

# %%
income.describe()
# Out:
# count    8.873750e+05
# mean     7.502759e+04
# std      6.469830e+04
# min      0.000000e+00
# 25%      4.500000e+04
# 50%      6.500000e+04
# 75%      9.000000e+04
# max      9.500000e+06
# Name: annual_inc, dtype: float64

# %%
income
# Out:
# 0               0.0
# 1               0.0
# 2            1200.0
# 3            1770.0
# 4            1896.0
#             ...
# 887370    8700000.0
# 887371    8706582.0
# 887372    8900060.0
# 887373    9000000.0
# 887374    9500000.0
# Name: annual_inc, Length: 887375, dtype: float64

# %%
upper_income = income.tail(100000)

# %%
ax = upper_income.plot.line()

# %%
upper_income
# Out:
# 787375     120000.0
# 787376     120000.0
# 787377     120000.0
# 787378     120000.0
# 787379     120000.0
#             ...
# 887370    8700000.0
# 887371    8706582.0
# 887372    8900060.0
# 887373    9000000.0
# 887374    9500000.0
# Name: annual_inc, Length: 100000, dtype: float64

# %%
upper_income.describe()
# Out:
# count    1.000000e+05
# mean     1.748310e+05
# std      1.460963e+05
# min      1.200000e+05
# 25%      1.300000e+05
# 50%      1.500000e+05
# 75%      1.800000e+05
# max      9.500000e+06
# Name: annual_inc, dtype: float64

# %% [markdown]
# # Results show that most of the people applying for a loan earn an income less than $200,000

# %%
bins = [0, 5000, 10000, 15000, 20000, 25000, 30000, 35000]
loan_amount = pd.DataFrame(df['loan_amnt'].value_counts(bins=bins))
loan_amount
# Out:
#                     loan_amnt
# (5000.0, 10000.0]      232900
# (10000.0, 15000.0]     199959
# (15000.0, 20000.0]     151003
# (-0.001, 5000.0]       102680
# (20000.0, 25000.0]      97170
# (25000.0, 30000.0]      54040
# (30000.0, 35000.0]      49627

# %%
loan_amount = loan_amount.sort_index()
loan_amount
# Out:
#                     loan_amnt
# (-0.001, 5000.0]       102680
# (5000.0, 10000.0]      232900
# (10000.0, 15000.0]     199959
# (15000.0, 20000.0]     151003
# (20000.0, 25000.0]      97170
# (25000.0, 30000.0]      54040
# (30000.0, 35000.0]      49627

# %%
labels = ['<=5000', '<=10000', '<=15000', '<=20000', '<=25000', '<=30000', '<=35000']
plt = pd.DataFrame({'lab':labels, 'loaners':[int(v) for v in loan_amount.values]})

# %%
ax = plt.plot.bar()
ax.set_xticks(range(len(labels)), labels, rotation = 20)

# %% [markdown]
# ### As we can see, most of the loan applications are between $5,000 - $10,000. While many of them are less than $25,000.
